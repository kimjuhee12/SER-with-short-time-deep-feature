# %% [markdown]
# # 1. Nils Ackermann, "Introduction to 1D Convolutional Neural Networks in Keras for Time Sequences", sep 4,2018,
#
#
# https://blog.goodaudience.com/introduction-to-1d-convolutional-neural-networks-in-keras-for-time-sequences-3a7ff801a2cf

# %% [markdown]
# - Conv1D layer -> Fully connected layer with softmax

# %% [markdown]
# ## 0. Import

# %%
from emotion_recognition import utils
from emotion_recognition import features

import numpy as np

import warnings

import keras
from keras.models import Sequential
from keras import layers

warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 1.1 Data preparation

# %% [markdown]
# - Setting parameters

# %%
window_size = 1000 # 특징 추출을 위한 윈도우 크기
frame_size = 500 # 음성구간 찾기 위한 프레임 크기 
class_size = 4 #class 크기
sr = 16000

# 0 = neutral, 1 = anger, 2 = happiness, 3 = sadness
emotion = ["neutral","anger","happiness","sadness"]

# %% [markdown]
# - Loading filelist

# %%
# 파일 이름 읽어오기
path = "../data/"
text_filename = "filelist_wav.txt"

filelist_wav = []
emotionlist = []

f = open(path+text_filename, 'r')

while True:
    line = f.readline()
    if not line: break
    
    filename, label = line.split()
    
    filelist_wav.append(filename)
    emotionlist.append(label)
    
f.close()

# %% [markdown]
# - Splitting the data into trainnnig and test
# - For test, subjects 1,6,7,11
# - For training, subjects 2,3,4,5,8,9,10,12,13,14,15,16,17,18,19,20

# %%
Training_filename = []
Training_emotionlist = []
Test_filename = []
Test_emotionlist = []

for i in range(len(filelist_wav)):
    if (filelist_wav[i].split("_")[0][1:] == '1'):
        Test_filename.append(filelist_wav[i])
        Test_emotionlist.append(emotionlist[i])
    elif (filelist_wav[i].split("_")[0][1:] == '6'):
        Test_filename.append(filelist_wav[i])
        Test_emotionlist.append(emotionlist[i])
    elif (filelist_wav[i].split("_")[0][1:] == '7'):
        Test_filename.append(filelist_wav[i])
        Test_emotionlist.append(emotionlist[i])
    elif (filelist_wav[i].split("_")[0][1:] == '11'):
        Test_filename.append(filelist_wav[i])
        Test_emotionlist.append(emotionlist[i])
    else:
        Training_filename.append(filelist_wav[i])
        Training_emotionlist.append(emotionlist[i])

# %%
print (np.shape(Training_filename))
print (np.shape(Test_filename))
# Out:
# (614,)
# (226,)

# %%
Training_vector = []
Training_label = []

for ix in range(len(Training_filename)):
    # 파일 읽어오기
    if Training_emotionlist[ix] == "excitement":
        continue
        
    if Training_emotionlist[ix] == "fear":
        continue
        
    print (str(ix)+ "\t" + Training_emotionlist[ix] + "\t" + path+'wav/' + Training_filename[ix])
    
    y,sr = utils.loadwav(path+'wav/' + Training_filename[ix])
    
    temp = emotion.index(Training_emotionlist[ix])    
    label = np.zeros(class_size)
    label[temp] = 1
    
    #파일 전체 길이
    length = len(y)
    
    idx = 0
    while(idx != length):
        #voice 구간 구하기
        IAV_th = utils.get_IAV_threshold(y,length,frame_size)
        th = IAV_th/frame_size*2
        
        start_point, end_point = utils.search_voicearea(y,frame_size,length,idx,th,IAV_th)
        
        if(start_point == -1):
            break
            
        idx = end_point
        
        segment_length = end_point-start_point+1
        
        # 음성 구간이 time_step 보다 짧으면 해당 음성 구간에서 특징 추출 x
        if(segment_length-window_size < 7000 ):
            continue
        
        # 세그먼트 추출
        for i in range(start_point,(end_point-window_size), window_size ):
            y_sub = y[i:i+window_size]
            
            Training_vector.append(y_sub)
            Training_label.append(label)
# Out:
# 0	sadness	../data/wav/s19_sadness_M_s17.wav
# 1	sadness	../data/wav/s18_sadness_F_s1.wav
# 4	anger	../data/wav/s15_anger_F_a11.wav
# 6	sadness	../data/wav/s19_sadness_M_s8.wav
# 8	neutral	../data/wav/s18_neutral_F_n14.wav
# 9	sadness	../data/wav/s20_sadness_F_s20.wav
# 11	happiness	../data/wav/s3_happiness_M_h10.wav
# 13	happiness	../data/wav/s5_happiness_M_h8.wav
# 14	sadness	../data/wav/s8_sadness_M_s17.wav
# 15	happiness	../data/wav/s5_happiness_M_h16.wav
# 16	happiness	../data/wav/s4_happiness_M_h10.wav
# 17	neutral	../data/wav/s9_neutral_M_n10.wav
# 20	anger	../data/wav/s19_anger_M_a18.wav
# 21	neutral	../data/wav/s15_neutral_F_n11.wav
# 22	anger	../data/wav/s14_anger_M_a17.wav
# 23	neutral	../data/wav/s12_neutral_F_n5.wav
# 24	neutral	../data/wav/s15_neutral_F_n16.wav
# 25	happiness	../data/wav/s19_happiness_M_h7.wav
# 28	happiness	../data/wav/s10_happiness_M_h10.wav
# 29	happiness	../data/wav/s20_happiness_F_h8.wav
# 30	happiness	../data/wav/s19_happiness_M_h8.wav
# 31	sadness	../data/wav/s12_sadness_F_s12.wav
# 32	neutral	../data/wav/s20_neutral_F_n20.wav
# 33	anger	../data/wav/s15_anger_F_a9.wav
# 34	sadness	../data/wav/s19_sadness_M_s5.wav
# 35	sadness	../data/wav/s9_sadness_M_s8.wav
# 36	anger	../data/wav/s13_anger_F_a9.wav
# 37	neutral	../data/wav/s8_neutral_M_n14.wav
# 38	neutral	../data/wav/s2_neutral_M_n16.wav
# 39	neutral	../data/wav/s19_neutral_M_n12.wav
# 40	sadness	../data/wav/s18_sadness_F_s9.wav
# 41	neutral	../data/wav/s12_neutral_F_n3.wav
# 42	sadness	../data/wav/s2_sadness_M_s15.wav
# 43	sadness	../data/wav/s18_sadness_F_s14.wav
# 44	anger	../data/wav/s5_anger_M_a20.wav
# 45	sadness	../data/wav/s10_sadness_M_s5.wav
# 46	anger	../data/wav/s19_anger_M_a15.wav
# 48	neutral	../data/wav/s12_neutral_F_n17.wav
# 49	happiness	../data/wav/s14_happiness_M_h18.wav
# 52	anger	../data/wav/s15_anger_F_a12.wav
# 55	neutral	../data/wav/s4_neutral_M_n19.wav
# 56	happiness	../data/wav/s3_happiness_M_h11.wav
# 58	neutral	../data/wav/s18_neutral_F_n11.wav
# 60	sadness	../data/wav/s18_sadness_F_s3.wav
# 61	neutral	../data/wav/s19_neutral_M_n4.wav
# 62	happiness	../data/wav/s3_happiness_M_h8.wav
# 63	anger	../data/wav/s2_anger_M_a5.wav
# 64	neutral	../data/wav/s12_neutral_F_n9.wav
# 65	neutral	../data/wav/s15_neutral_F_n4.wav
# 66	neutral	../data/wav/s18_neutral_F_n7.wav
# 68	happiness	../data/wav/s19_happiness_M_h14.wav
# 70	happiness	../data/wav/s18_happiness_F_h4.wav
# 71	anger	../data/wav/s5_anger_M_a6.wav
# 72	neutral	../data/wav/s12_neutral_F_n15.wav
# 74	anger	../data/wav/s20_anger_F_a7.wav
# 76	happiness	../data/wav/s13_happiness_F_h2.wav
# 77	sadness	../data/wav/s13_sadness_F_s6.wav
# 79	neutral	../data/wav/s15_neutral_F_n14.wav
# 80	happiness	../data/wav/s18_happiness_F_h1.wav
# 81	sadness	../data/wav/s20_sadness_F_s9.wav
# 82	anger	../data/wav/s19_anger_M_a20.wav
# 85	neutral	../data/wav/s19_neutral_M_n5.wav
# 86	anger	../data/wav/s3_anger_M_a15.wav
# 88	neutral	../data/wav/s2_neutral_M_n5.wav
# 89	sadness	../data/wav/s10_sadness_M_s2.wav
# 91	anger	../data/wav/s12_anger_F_a7.wav
# 96	happiness	../data/wav/s19_happiness_M_h2.wav
# 98	anger	../data/wav/s5_anger_M_a14.wav
# 100	sadness	../data/wav/s9_sadness_M_s11.wav
# 101	neutral	../data/wav/s2_neutral_M_n15.wav
# 102	anger	../data/wav/s15_anger_F_a3.wav
# 105	sadness	../data/wav/s9_sadness_M_s10.wav
# 106	sadness	../data/wav/s18_sadness_F_s16.wav
# 109	neutral	../data/wav/s15_neutral_F_n6.wav
# 113	neutral	../data/wav/s18_neutral_F_n5.wav
# 114	neutral	../data/wav/s2_neutral_M_n8.wav
# 117	happiness	../data/wav/s19_happiness_M_h1.wav
# 118	happiness	../data/wav/s13_happiness_F_h3.wav
# 120	sadness	../data/wav/s10_sadness_M_s15.wav
# 121	happiness	../data/wav/s3_happiness_M_h12.wav
# 122	neutral	../data/wav/s18_neutral_F_n10.wav
# 124	sadness	../data/wav/s9_sadness_M_s5.wav
# 125	anger	../data/wav/s18_anger_F_a10.wav
# 127	happiness	../data/wav/s4_happiness_M_h18.wav
# 129	sadness	../data/wav/s2_sadness_M_s17.wav
# 130	happiness	../data/wav/s18_happiness_F_h13.wav
# 131	sadness	../data/wav/s10_sadness_M_s20.wav
# 132	sadness	../data/wav/s20_sadness_F_s4.wav
# 133	anger	../data/wav/s9_anger_M_a1.wav
# 134	happiness	../data/wav/s3_happiness_M_h14.wav
# 136	anger	../data/wav/s5_anger_M_a7.wav
# 139	anger	../data/wav/s12_anger_F_a16.wav
# 140	anger	../data/wav/s19_anger_M_a11.wav
# 141	anger	../data/wav/s9_anger_M_a7.wav
# 143	happiness	../data/wav/s15_happiness_F_h15.wav
# 146	anger	../data/wav/s18_anger_F_a17.wav
# 149	neutral	../data/wav/s13_neutral_F_n19.wav
# 150	anger	../data/wav/s5_anger_M_a18.wav
# 151	neutral	../data/wav/s13_neutral_F_n20.wav
# 152	anger	../data/wav/s18_anger_F_a15.wav
# 153	neutral	../data/wav/s8_neutral_M_n4.wav
# 156	sadness	../data/wav/s2_sadness_M_s16.wav
# 157	happiness	../data/wav/s3_happiness_M_h18.wav
# 158	happiness	../data/wav/s15_happiness_F_h17.wav
# 159	happiness	../data/wav/s15_happiness_F_h14.wav
# 161	happiness	../data/wav/s4_happiness_M_h14.wav
# 162	sadness	../data/wav/s9_sadness_M_s13.wav
# 163	neutral	../data/wav/s20_neutral_F_n5.wav
# 164	happiness	../data/wav/s3_happiness_M_h2.wav
# 165	sadness	../data/wav/s14_sadness_M_s9.wav
# 168	sadness	../data/wav/s2_sadness_M_s20.wav
# 169	happiness	../data/wav/s19_happiness_M_h13.wav
# 170	happiness	../data/wav/s10_happiness_M_h5.wav
# 171	anger	../data/wav/s19_anger_M_a13.wav
# 172	neutral	../data/wav/s12_neutral_F_n20.wav
# 175	anger	../data/wav/s9_anger_M_a8.wav
# 177	sadness	../data/wav/s5_sadness_M_s19.wav
# 179	neutral	../data/wav/s8_neutral_M_n13.wav
# 180	anger	../data/wav/s2_anger_M_a8.wav
# 181	sadness	../data/wav/s5_sadness_M_s1.wav
# 182	happiness	../data/wav/s13_happiness_F_h10.wav
# 184	anger	../data/wav/s12_anger_F_a17.wav
# 185	sadness	../data/wav/s18_sadness_F_s4.wav
# 186	neutral	../data/wav/s2_neutral_M_n20.wav
# 187	anger	../data/wav/s12_anger_F_a8.wav
# 188	neutral	../data/wav/s9_neutral_M_n14.wav
# 189	neutral	../data/wav/s15_neutral_F_n12.wav
# 191	happiness	../data/wav/s4_happiness_M_h12.wav
# 192	happiness	../data/wav/s18_happiness_F_h14.wav
# 193	neutral	../data/wav/s2_neutral_M_n12.wav
# 196	sadness	../data/wav/s19_sadness_M_s18.wav
# 197	happiness	../data/wav/s19_happiness_M_h4.wav
# 198	sadness	../data/wav/s20_sadness_F_s14.wav
# 199	anger	../data/wav/s19_anger_M_a12.wav
# 200	happiness	../data/wav/s10_happiness_M_h16.wav
# 202	neutral	../data/wav/s19_neutral_M_n17.wav
# 205	neutral	../data/wav/s12_neutral_F_n13.wav
# 206	anger	../data/wav/s10_anger_M_a6.wav
# 209	happiness	../data/wav/s18_happiness_F_h8.wav
# 210	neutral	../data/wav/s8_neutral_M_n18.wav
# 212	sadness	../data/wav/s13_sadness_F_s13.wav
# 215	happiness	../data/wav/s3_happiness_M_h16.wav
# 217	neutral	../data/wav/s9_neutral_M_n16.wav
# 219	sadness	../data/wav/s19_sadness_M_s3.wav
# 220	neutral	../data/wav/s20_neutral_F_n8.wav
# 221	anger	../data/wav/s20_anger_F_a19.wav
# 223	sadness	../data/wav/s12_sadness_F_s4.wav
# 224	happiness	../data/wav/s9_happiness_M_h15.wav
# 225	neutral	../data/wav/s15_neutral_F_n5.wav
# 226	anger	../data/wav/s15_anger_F_a10.wav
# 227	sadness	../data/wav/s10_sadness_M_s9.wav
# 229	sadness	../data/wav/s9_sadness_M_s14.wav
# 230	neutral	../data/wav/s2_neutral_M_n18.wav
# 231	anger	../data/wav/s12_anger_F_a14.wav
# 232	anger	../data/wav/s12_anger_F_a4.wav
# 234	happiness	../data/wav/s13_happiness_F_h14.wav
# 236	happiness	../data/wav/s10_happiness_M_h13.wav
# 238	happiness	../data/wav/s15_happiness_F_h12.wav
# 241	anger	../data/wav/s15_anger_F_a19.wav
# 245	neutral	../data/wav/s15_neutral_F_n13.wav
# 247	anger	../data/wav/s9_anger_M_a4.wav
# 249	anger	../data/wav/s14_anger_M_a7.wav
# 250	happiness	../data/wav/s10_happiness_M_h15.wav
# 251	neutral	../data/wav/s15_neutral_F_n17.wav
# 252	happiness	../data/wav/s18_happiness_F_h3.wav
# 253	sadness	../data/wav/s2_sadness_M_s8.wav
# 255	anger	../data/wav/s5_anger_M_a15.wav
# 257	happiness	../data/wav/s13_happiness_F_h16.wav
# 259	anger	../data/wav/s5_anger_M_a19.wav
# 262	sadness	../data/wav/s14_sadness_M_s13.wav
# 263	happiness	../data/wav/s9_happiness_M_h12.wav
# 264	sadness	../data/wav/s15_sadness_F_s18.wav
# 265	anger	../data/wav/s15_anger_F_a13.wav
# 266	happiness	../data/wav/s19_happiness_M_h12.wav
# 267	neutral	../data/wav/s13_neutral_F_n1.wav
# 268	anger	../data/wav/s20_anger_F_a15.wav
# 269	neutral	../data/wav/s18_neutral_F_n1.wav
# 271	anger	../data/wav/s9_anger_M_a10.wav
# 273	anger	../data/wav/s15_anger_F_a20.wav
# 274	neutral	../data/wav/s13_neutral_F_n8.wav
# 275	sadness	../data/wav/s15_sadness_F_s10.wav
# 276	sadness	../data/wav/s10_sadness_M_s4.wav
# 278	happiness	../data/wav/s20_happiness_F_h10.wav
# 279	happiness	../data/wav/s19_happiness_M_h10.wav
# 281	sadness	../data/wav/s18_sadness_F_s13.wav
# 282	happiness	../data/wav/s19_happiness_M_h9.wav
# 284	neutral	../data/wav/s9_neutral_M_n13.wav
# 285	happiness	../data/wav/s12_happiness_F_h4.wav
# 287	anger	../data/wav/s13_anger_F_a12.wav
# 288	happiness	../data/wav/s10_happiness_M_h14.wav
# 289	happiness	../data/wav/s2_happiness_M_h18.wav
# 290	neutral	../data/wav/s19_neutral_M_n13.wav
# 291	neutral	../data/wav/s13_neutral_F_n13.wav
# 292	sadness	../data/wav/s15_sadness_F_s5.wav
# 294	anger	../data/wav/s5_anger_M_a8.wav
# 296	sadness	../data/wav/s4_sadness_M_s18.wav
# 298	sadness	../data/wav/s4_sadness_M_s17.wav
# 299	sadness	../data/wav/s9_sadness_M_s1.wav
# 301	sadness	../data/wav/s10_sadness_M_s12.wav
# 302	happiness	../data/wav/s8_happiness_M_h5.wav
# 303	anger	../data/wav/s15_anger_F_a17.wav
# 304	neutral	../data/wav/s12_neutral_F_n12.wav
# 305	sadness	../data/wav/s15_sadness_F_s15.wav
# 306	anger	../data/wav/s15_anger_F_a16.wav
# 307	neutral	../data/wav/s14_neutral_M_n20.wav
# 308	neutral	../data/wav/s14_neutral_M_n13.wav
# 311	neutral	../data/wav/s9_neutral_M_n2.wav
# 312	neutral	../data/wav/s3_neutral_M_n13.wav
# 313	neutral	../data/wav/s2_neutral_M_n14.wav
# 315	sadness	../data/wav/s18_sadness_F_s8.wav
# 316	neutral	../data/wav/s18_neutral_F_n19.wav
# 319	neutral	../data/wav/s8_neutral_M_n8.wav
# 320	neutral	../data/wav/s3_neutral_M_n5.wav
# 321	neutral	../data/wav/s13_neutral_F_n12.wav
# 324	anger	../data/wav/s3_anger_M_a9.wav
# 326	happiness	../data/wav/s15_happiness_F_h16.wav
# 327	neutral	../data/wav/s12_neutral_F_n18.wav
# 328	neutral	../data/wav/s19_neutral_M_n20.wav
# 329	anger	../data/wav/s12_anger_F_a13.wav
# 331	sadness	../data/wav/s18_sadness_F_s15.wav
# 332	happiness	../data/wav/s15_happiness_F_h10.wav
# 333	neutral	../data/wav/s19_neutral_M_n11.wav
# 334	sadness	../data/wav/s20_sadness_F_s13.wav
# 336	neutral	../data/wav/s15_neutral_F_n8.wav
# 337	happiness	../data/wav/s3_happiness_M_h6.wav
# 340	happiness	../data/wav/s13_happiness_F_h19.wav
# 341	anger	../data/wav/s13_anger_F_a4.wav
# 343	anger	../data/wav/s9_anger_M_a17.wav
# 344	happiness	../data/wav/s18_happiness_F_h15.wav
# 347	happiness	../data/wav/s19_happiness_M_h5.wav
# 348	sadness	../data/wav/s20_sadness_F_s5.wav
# 351	sadness	../data/wav/s14_sadness_M_s10.wav
# 352	neutral	../data/wav/s15_neutral_F_n15.wav
# 353	happiness	../data/wav/s19_happiness_M_h15.wav
# 355	neutral	../data/wav/s9_neutral_M_n17.wav
# 356	anger	../data/wav/s12_anger_F_a20.wav
# 357	happiness	../data/wav/s10_happiness_M_h8.wav
# 360	anger	../data/wav/s19_anger_M_a2.wav
# 362	happiness	../data/wav/s3_happiness_M_h19.wav
# 363	sadness	../data/wav/s19_sadness_M_s6.wav
# 364	happiness	../data/wav/s16_happiness_M_h11.wav
# 365	sadness	../data/wav/s14_sadness_M_s18.wav
# 370	happiness	../data/wav/s5_happiness_M_h14.wav
# 371	sadness	../data/wav/s10_sadness_M_s7.wav
# 372	neutral	../data/wav/s3_neutral_M_n14.wav
# 373	neutral	../data/wav/s8_neutral_M_n5.wav
# 374	neutral	../data/wav/s9_neutral_M_n9.wav
# 376	happiness	../data/wav/s13_happiness_F_h7.wav
# 377	sadness	../data/wav/s14_sadness_M_s7.wav
# 378	anger	../data/wav/s15_anger_F_a6.wav
# 381	happiness	../data/wav/s4_happiness_M_h2.wav
# 382	neutral	../data/wav/s19_neutral_M_n15.wav
# 384	neutral	../data/wav/s12_neutral_F_n14.wav
# 385	happiness	../data/wav/s4_happiness_M_h5.wav
# 386	neutral	../data/wav/s2_neutral_M_n17.wav
# 388	happiness	../data/wav/s12_happiness_F_h11.wav
# 389	neutral	../data/wav/s15_neutral_F_n7.wav
# 390	neutral	../data/wav/s18_neutral_F_n17.wav
# 392	happiness	../data/wav/s10_happiness_M_h9.wav
# 393	neutral	../data/wav/s15_neutral_F_n10.wav
# 394	sadness	../data/wav/s18_sadness_F_s19.wav
# 395	sadness	../data/wav/s12_sadness_F_s17.wav
# 396	anger	../data/wav/s5_anger_M_a17.wav
# 397	sadness	../data/wav/s12_sadness_F_s7.wav
# 399	happiness	../data/wav/s15_happiness_F_h20.wav
# 400	happiness	../data/wav/s4_happiness_M_h20.wav
# 402	happiness	../data/wav/s3_happiness_M_h13.wav
# 403	neutral	../data/wav/s18_neutral_F_n8.wav
# 404	neutral	../data/wav/s3_neutral_M_n7.wav
# 405	neutral	../data/wav/s18_neutral_F_n15.wav
# 408	sadness	../data/wav/s13_sadness_F_s11.wav
# 409	anger	../data/wav/s5_anger_M_a13.wav
# 410	anger	../data/wav/s5_anger_M_a10.wav
# 412	happiness	../data/wav/s10_happiness_M_h12.wav
# 413	happiness	../data/wav/s18_happiness_F_h10.wav
# 414	neutral	../data/wav/s12_neutral_F_n16.wav
# 415	sadness	../data/wav/s2_sadness_M_s6.wav
# 419	sadness	../data/wav/s10_sadness_M_s18.wav
# 422	sadness	../data/wav/s13_sadness_F_s20.wav
# 423	happiness	../data/wav/s15_happiness_F_h7.wav
# 424	anger	../data/wav/s14_anger_M_a20.wav
# 426	sadness	../data/wav/s4_sadness_M_s13.wav
# 427	anger	../data/wav/s12_anger_F_a9.wav
# 428	neutral	../data/wav/s9_neutral_M_n8.wav
# 430	neutral	../data/wav/s12_neutral_F_n7.wav
# 431	happiness	../data/wav/s20_happiness_F_h18.wav
# 432	happiness	../data/wav/s18_happiness_F_h2.wav
# 433	anger	../data/wav/s5_anger_M_a11.wav
# 434	anger	../data/wav/s13_anger_F_a17.wav
# 435	anger	../data/wav/s5_anger_M_a9.wav
# 436	neutral	../data/wav/s19_neutral_M_n19.wav
# 437	sadness	../data/wav/s10_sadness_M_s10.wav
# 439	anger	../data/wav/s2_anger_M_a7.wav
# 440	happiness	../data/wav/s17_happiness_M_h2.wav
# 443	neutral	../data/wav/s18_neutral_F_n6.wav
# 444	neutral	../data/wav/s12_neutral_F_n10.wav
# 446	happiness	../data/wav/s15_happiness_F_h11.wav
# 447	neutral	../data/wav/s19_neutral_M_n8.wav
# 450	neutral	../data/wav/s8_neutral_M_n7.wav
# 453	happiness	../data/wav/s20_happiness_F_h15.wav
# 454	happiness	../data/wav/s9_happiness_M_h10.wav
# 455	sadness	../data/wav/s2_sadness_M_s4.wav
# 456	happiness	../data/wav/s20_happiness_F_h16.wav
# 458	neutral	../data/wav/s9_neutral_M_n12.wav
# 463	anger	../data/wav/s19_anger_M_a17.wav
# 464	sadness	../data/wav/s18_sadness_F_s5.wav
# 468	sadness	../data/wav/s15_sadness_F_s14.wav
# 469	anger	../data/wav/s5_anger_M_a5.wav
# 470	sadness	../data/wav/s20_sadness_F_s7.wav
# 471	sadness	../data/wav/s17_sadness_M_s12.wav
# 472	anger	../data/wav/s15_anger_F_a8.wav
# 473	sadness	../data/wav/s20_sadness_F_s16.wav
# 474	neutral	../data/wav/s12_neutral_F_n6.wav
# 476	neutral	../data/wav/s18_neutral_F_n4.wav
# 480	happiness	../data/wav/s3_happiness_M_h4.wav
# 481	anger	../data/wav/s12_anger_F_a10.wav
# 482	anger	../data/wav/s12_anger_F_a19.wav
# 484	anger	../data/wav/s5_anger_M_a4.wav
# 485	neutral	../data/wav/s9_neutral_M_n19.wav
# 488	anger	../data/wav/s3_anger_M_a19.wav
# 489	anger	../data/wav/s10_anger_M_a17.wav
# 491	sadness	../data/wav/s20_sadness_F_s3.wav
# 492	happiness	../data/wav/s3_happiness_M_h5.wav
# 493	anger	../data/wav/s13_anger_F_a14.wav
# 494	sadness	../data/wav/s12_sadness_F_s9.wav
# 495	neutral	../data/wav/s9_neutral_M_n20.wav
# 496	sadness	../data/wav/s14_sadness_M_s17.wav
# 498	anger	../data/wav/s17_anger_M_a17.wav
# 499	anger	../data/wav/s9_anger_M_a18.wav
# 500	anger	../data/wav/s18_anger_F_a19.wav
# 501	anger	../data/wav/s19_anger_M_a16.wav
# 503	neutral	../data/wav/s18_neutral_F_n16.wav
# 504	anger	../data/wav/s13_anger_F_a13.wav
# 505	anger	../data/wav/s15_anger_F_a15.wav
# 506	sadness	../data/wav/s12_sadness_F_s6.wav
# 507	happiness	../data/wav/s19_happiness_M_h11.wav
# 509	neutral	../data/wav/s3_neutral_M_n11.wav
# 510	happiness	../data/wav/s3_happiness_M_h7.wav
# 511	neutral	../data/wav/s8_neutral_M_n17.wav
# 513	neutral	../data/wav/s19_neutral_M_n1.wav
# 516	sadness	../data/wav/s20_sadness_F_s17.wav
# 517	neutral	../data/wav/s12_neutral_F_n11.wav
# 521	happiness	../data/wav/s13_happiness_F_h6.wav
# 522	happiness	../data/wav/s9_happiness_M_h18.wav
# 524	sadness	../data/wav/s2_sadness_M_s10.wav
# 525	happiness	../data/wav/s4_happiness_M_h8.wav
# 527	neutral	../data/wav/s19_neutral_M_n2.wav
# 528	sadness	../data/wav/s20_sadness_F_s12.wav
# 529	neutral	../data/wav/s12_neutral_F_n4.wav
# 530	neutral	../data/wav/s19_neutral_M_n14.wav
# 531	sadness	../data/wav/s12_sadness_F_s5.wav
# 535	happiness	../data/wav/s18_happiness_F_h12.wav
# 536	sadness	../data/wav/s15_sadness_F_s17.wav
# 538	neutral	../data/wav/s19_neutral_M_n16.wav
# 539	happiness	../data/wav/s18_happiness_F_h11.wav
# 540	sadness	../data/wav/s9_sadness_M_s9.wav
# 541	sadness	../data/wav/s9_sadness_M_s17.wav
# 544	anger	../data/wav/s18_anger_F_a20.wav
# 545	sadness	../data/wav/s20_sadness_F_s15.wav
# 546	anger	../data/wav/s5_anger_M_a16.wav
# 547	neutral	../data/wav/s8_neutral_M_n20.wav
# 548	happiness	../data/wav/s9_happiness_M_h14.wav
# 549	happiness	../data/wav/s15_happiness_F_h6.wav
# 550	happiness	../data/wav/s13_happiness_F_h12.wav
# 551	sadness	../data/wav/s10_sadness_M_s13.wav
# 552	sadness	../data/wav/s10_sadness_M_s6.wav
# 553	neutral	../data/wav/s18_neutral_F_n9.wav
# 554	happiness	../data/wav/s15_happiness_F_h13.wav
# 559	happiness	../data/wav/s3_happiness_M_h1.wav
# 560	sadness	../data/wav/s9_sadness_M_s19.wav
# 561	neutral	../data/wav/s12_neutral_F_n8.wav
# 563	sadness	../data/wav/s2_sadness_M_s18.wav
# 564	happiness	../data/wav/s9_happiness_M_h16.wav
# 565	anger	../data/wav/s9_anger_M_a11.wav
# 566	neutral	../data/wav/s3_neutral_M_n16.wav
# 567	anger	../data/wav/s19_anger_M_a19.wav
# 568	sadness	../data/wav/s13_sadness_F_s5.wav
# 569	sadness	../data/wav/s13_sadness_F_s12.wav
# 574	sadness	../data/wav/s18_sadness_F_s17.wav
# 576	neutral	../data/wav/s14_neutral_M_n14.wav
# 577	happiness	../data/wav/s9_happiness_M_h4.wav
# 580	neutral	../data/wav/s3_neutral_M_n8.wav
# 582	happiness	../data/wav/s12_happiness_F_h12.wav
# 583	sadness	../data/wav/s10_sadness_M_s17.wav
# 585	sadness	../data/wav/s19_sadness_M_s2.wav
# 586	sadness	../data/wav/s17_sadness_M_s16.wav
# 588	anger	../data/wav/s18_anger_F_a16.wav
# 589	sadness	../data/wav/s4_sadness_M_s14.wav
# 590	happiness	../data/wav/s19_happiness_M_h16.wav
# 591	anger	../data/wav/s15_anger_F_a14.wav
# 592	sadness	../data/wav/s13_sadness_F_s17.wav
# 594	sadness	../data/wav/s9_sadness_M_s18.wav
# 595	sadness	../data/wav/s20_sadness_F_s6.wav
# 596	anger	../data/wav/s12_anger_F_a2.wav
# 598	neutral	../data/wav/s9_neutral_M_n18.wav
# 599	sadness	../data/wav/s10_sadness_M_s14.wav
# 603	anger	../data/wav/s19_anger_M_a7.wav
# 604	anger	../data/wav/s12_anger_F_a5.wav
# 605	neutral	../data/wav/s19_neutral_M_n10.wav
# 606	happiness	../data/wav/s3_happiness_M_h15.wav
# 607	sadness	../data/wav/s20_sadness_F_s11.wav
# 609	anger	../data/wav/s14_anger_M_a4.wav
# 610	happiness	../data/wav/s15_happiness_F_h8.wav
# 611	sadness	../data/wav/s19_sadness_M_s7.wav
# 613	sadness	../data/wav/s14_sadness_M_s16.wav

# %%
Test_vector = []
Test_label = []

for ix in range(len(Test_filename)):
    # 파일 읽어오기
    if Test_emotionlist[ix] == "excitement":
        continue
        
    if Test_emotionlist[ix] == "fear":
        continue
        
    print (str(ix)+ "\t" + Test_emotionlist[ix] + "\t" + path+'wav/' + Test_filename[ix])
    
    y,sr = utils.loadwav(path+'wav/' + Test_filename[ix])
    
    temp = emotion.index(Test_emotionlist[ix])    
    label = np.zeros(class_size)
    label[temp] = 1
    
    #파일 전체 길이
    length = len(y)
    
    idx = 0
    while(idx != length):
        #voice 구간 구하기
        IAV_th = utils.get_IAV_threshold(y,length,frame_size)
        th = IAV_th/frame_size*2
        
        start_point, end_point = utils.search_voicearea(y,frame_size,length,idx,th,IAV_th)
        
        if(start_point == -1):
            break
            
        idx = end_point
        
        segment_length = end_point-start_point+1
        
        # 음성 구간이 time_step 보다 짧으면 해당 음성 구간에서 특징 추출 x
        if(segment_length-window_size < 7000 ):
            continue
        
        # 세그먼트 추출
        for i in range(start_point,(end_point-window_size), window_size ):
            y_sub = y[i:i+window_size]
            
            Test_vector.append(y_sub)
            Test_label.append(label)
# Out:
# 1	sadness	../data/wav/s7_sadness_M_s1.wav
# 2	happiness	../data/wav/s11_happiness_F_h20.wav
# 3	sadness	../data/wav/s11_sadness_F_s1.wav
# 4	sadness	../data/wav/s11_sadness_F_s9.wav
# 9	neutral	../data/wav/s1_neutral_M_n20.wav
# 10	sadness	../data/wav/s6_sadness_F_s18.wav
# 11	anger	../data/wav/s1_anger_M_a4.wav
# 13	happiness	../data/wav/s6_happiness_F_h14.wav
# 14	happiness	../data/wav/s11_happiness_F_h15.wav
# 16	anger	../data/wav/s6_anger_F_a12.wav
# 18	sadness	../data/wav/s11_sadness_F_s17.wav
# 19	happiness	../data/wav/s6_happiness_F_h1.wav
# 21	sadness	../data/wav/s6_sadness_F_s10.wav
# 24	happiness	../data/wav/s6_happiness_F_h15.wav
# 26	neutral	../data/wav/s6_neutral_F_n15.wav
# 27	sadness	../data/wav/s7_sadness_M_s15.wav
# 28	happiness	../data/wav/s6_happiness_F_h4.wav
# 29	sadness	../data/wav/s7_sadness_M_s11.wav
# 30	sadness	../data/wav/s6_sadness_F_s12.wav
# 31	anger	../data/wav/s7_anger_M_a17.wav
# 32	neutral	../data/wav/s1_neutral_M_n13.wav
# 33	anger	../data/wav/s11_anger_F_a16.wav
# 34	sadness	../data/wav/s7_sadness_M_s20.wav
# 35	happiness	../data/wav/s11_happiness_F_h16.wav
# 36	happiness	../data/wav/s6_happiness_F_h19.wav
# 37	happiness	../data/wav/s6_happiness_F_h12.wav
# 38	anger	../data/wav/s1_anger_M_a17.wav
# 39	sadness	../data/wav/s6_sadness_F_s13.wav
# 40	anger	../data/wav/s1_anger_M_a7.wav
# 41	happiness	../data/wav/s11_happiness_F_h5.wav
# 42	anger	../data/wav/s1_anger_M_a11.wav
# 43	anger	../data/wav/s1_anger_M_a2.wav
# 44	neutral	../data/wav/s1_neutral_M_n10.wav
# 45	anger	../data/wav/s7_anger_M_a3.wav
# 46	anger	../data/wav/s6_anger_F_a11.wav
# 47	happiness	../data/wav/s6_happiness_F_h18.wav
# 48	sadness	../data/wav/s11_sadness_F_s12.wav
# 49	neutral	../data/wav/s7_neutral_M_n5.wav
# 51	neutral	../data/wav/s6_neutral_F_n8.wav
# 54	anger	../data/wav/s6_anger_F_a6.wav
# 56	happiness	../data/wav/s7_happiness_M_h10.wav
# 57	anger	../data/wav/s6_anger_F_a15.wav
# 58	anger	../data/wav/s1_anger_M_a16.wav
# 59	anger	../data/wav/s1_anger_M_a3.wav
# 60	happiness	../data/wav/s7_happiness_M_h3.wav
# 62	happiness	../data/wav/s11_happiness_F_h17.wav
# 63	sadness	../data/wav/s6_sadness_F_s20.wav
# 67	neutral	../data/wav/s6_neutral_F_n16.wav
# 68	anger	../data/wav/s11_anger_F_a5.wav
# 69	neutral	../data/wav/s6_neutral_F_n4.wav
# 73	anger	../data/wav/s11_anger_F_a13.wav
# 75	anger	../data/wav/s6_anger_F_a2.wav
# 76	sadness	../data/wav/s7_sadness_M_s17.wav
# 77	anger	../data/wav/s7_anger_M_a6.wav
# 79	happiness	../data/wav/s7_happiness_M_h14.wav
# 81	sadness	../data/wav/s7_sadness_M_s9.wav
# 82	neutral	../data/wav/s1_neutral_M_n11.wav
# 83	anger	../data/wav/s7_anger_M_a12.wav
# 86	neutral	../data/wav/s6_neutral_F_n17.wav
# 87	neutral	../data/wav/s11_neutral_F_n17.wav
# 88	anger	../data/wav/s11_anger_F_a19.wav
# 90	anger	../data/wav/s1_anger_M_a9.wav
# 91	happiness	../data/wav/s6_happiness_F_h5.wav
# 93	sadness	../data/wav/s6_sadness_F_s16.wav
# 95	anger	../data/wav/s11_anger_F_a15.wav
# 96	sadness	../data/wav/s7_sadness_M_s4.wav
# 97	anger	../data/wav/s7_anger_M_a16.wav
# 98	neutral	../data/wav/s7_neutral_M_n3.wav
# 99	happiness	../data/wav/s6_happiness_F_h16.wav
# 100	anger	../data/wav/s6_anger_F_a16.wav
# 101	anger	../data/wav/s6_anger_F_a7.wav
# 102	sadness	../data/wav/s11_sadness_F_s10.wav
# 103	anger	../data/wav/s7_anger_M_a18.wav
# 104	neutral	../data/wav/s11_neutral_F_n8.wav
# 105	neutral	../data/wav/s11_neutral_F_n3.wav
# 106	sadness	../data/wav/s6_sadness_F_s19.wav
# 107	sadness	../data/wav/s6_sadness_F_s1.wav
# 108	anger	../data/wav/s6_anger_F_a3.wav
# 110	anger	../data/wav/s11_anger_F_a14.wav
# 114	sadness	../data/wav/s7_sadness_M_s19.wav
# 116	happiness	../data/wav/s11_happiness_F_h18.wav
# 117	anger	../data/wav/s11_anger_F_a9.wav
# 118	sadness	../data/wav/s11_sadness_F_s19.wav
# 119	anger	../data/wav/s11_anger_F_a12.wav
# 121	anger	../data/wav/s6_anger_F_a18.wav
# 123	anger	../data/wav/s6_anger_F_a10.wav
# 124	sadness	../data/wav/s11_sadness_F_s4.wav
# 125	sadness	../data/wav/s6_sadness_F_s17.wav
# 126	neutral	../data/wav/s6_neutral_F_n5.wav
# 127	sadness	../data/wav/s7_sadness_M_s2.wav
# 128	anger	../data/wav/s6_anger_F_a5.wav
# 129	neutral	../data/wav/s11_neutral_F_n20.wav
# 131	happiness	../data/wav/s6_happiness_F_h17.wav
# 132	anger	../data/wav/s6_anger_F_a1.wav
# 135	sadness	../data/wav/s11_sadness_F_s5.wav
# 136	sadness	../data/wav/s6_sadness_F_s14.wav
# 139	anger	../data/wav/s6_anger_F_a20.wav
# 141	anger	../data/wav/s7_anger_M_a2.wav
# 142	happiness	../data/wav/s6_happiness_F_h6.wav
# 145	happiness	../data/wav/s11_happiness_F_h13.wav
# 146	anger	../data/wav/s6_anger_F_a13.wav
# 147	happiness	../data/wav/s1_happiness_M_h16.wav
# 149	anger	../data/wav/s6_anger_F_a9.wav
# 150	sadness	../data/wav/s7_sadness_M_s10.wav
# 151	neutral	../data/wav/s7_neutral_M_n1.wav
# 152	anger	../data/wav/s7_anger_M_a5.wav
# 153	happiness	../data/wav/s11_happiness_F_h6.wav
# 156	neutral	../data/wav/s11_neutral_F_n14.wav
# 158	neutral	../data/wav/s7_neutral_M_n2.wav
# 161	happiness	../data/wav/s7_happiness_M_h15.wav
# 162	happiness	../data/wav/s11_happiness_F_h19.wav
# 163	sadness	../data/wav/s11_sadness_F_s6.wav
# 164	happiness	../data/wav/s11_happiness_F_h12.wav
# 165	anger	../data/wav/s6_anger_F_a8.wav
# 166	anger	../data/wav/s7_anger_M_a4.wav
# 167	sadness	../data/wav/s7_sadness_M_s16.wav
# 169	happiness	../data/wav/s6_happiness_F_h7.wav
# 171	anger	../data/wav/s6_anger_F_a17.wav
# 172	happiness	../data/wav/s6_happiness_F_h20.wav
# 173	neutral	../data/wav/s1_neutral_M_n8.wav
# 174	happiness	../data/wav/s11_happiness_F_h7.wav
# 175	sadness	../data/wav/s6_sadness_F_s9.wav
# 176	anger	../data/wav/s6_anger_F_a14.wav
# 177	happiness	../data/wav/s6_happiness_F_h13.wav
# 178	sadness	../data/wav/s6_sadness_F_s8.wav
# 179	sadness	../data/wav/s6_sadness_F_s15.wav
# 180	anger	../data/wav/s6_anger_F_a19.wav
# 181	happiness	../data/wav/s6_happiness_F_h8.wav
# 182	sadness	../data/wav/s1_sadness_M_s4.wav
# 184	happiness	../data/wav/s6_happiness_F_h11.wav
# 185	sadness	../data/wav/s11_sadness_F_s20.wav
# 186	neutral	../data/wav/s7_neutral_M_n4.wav
# 189	happiness	../data/wav/s7_happiness_M_h20.wav
# 194	neutral	../data/wav/s1_neutral_M_n12.wav
# 195	anger	../data/wav/s1_anger_M_a10.wav
# 196	neutral	../data/wav/s1_neutral_M_n16.wav
# 198	neutral	../data/wav/s11_neutral_F_n10.wav
# 201	happiness	../data/wav/s7_happiness_M_h2.wav
# 202	happiness	../data/wav/s11_happiness_F_h10.wav
# 203	anger	../data/wav/s1_anger_M_a6.wav
# 205	happiness	../data/wav/s6_happiness_F_h10.wav
# 206	anger	../data/wav/s6_anger_F_a4.wav
# 207	happiness	../data/wav/s11_happiness_F_h11.wav
# 208	neutral	../data/wav/s6_neutral_F_n20.wav
# 209	neutral	../data/wav/s11_neutral_F_n5.wav
# 211	neutral	../data/wav/s11_neutral_F_n12.wav
# 213	anger	../data/wav/s1_anger_M_a14.wav
# 214	neutral	../data/wav/s11_neutral_F_n13.wav
# 215	sadness	../data/wav/s11_sadness_F_s8.wav
# 216	anger	../data/wav/s7_anger_M_a10.wav
# 218	neutral	../data/wav/s7_neutral_M_n19.wav
# 219	neutral	../data/wav/s7_neutral_M_n8.wav
# 223	happiness	../data/wav/s7_happiness_M_h5.wav
# 224	anger	../data/wav/s7_anger_M_a7.wav
# 225	neutral	../data/wav/s11_neutral_F_n4.wav

# %%
print (np.shape(Training_vector), np.shape(Test_vector))
# Out:
# (20250, 1000) (7835, 1000)

# %%
import math

for i in range(len(Training_vector)):
    Training_vector[i] = Training_vector[i] * 2 / math.pow(2,16)
    
for i in range(len(Test_vector)):
    Test_vector[i] = Test_vector[i] * 2 / math.pow(2,16)

# %%
Training_vector = np.expand_dims(Training_vector,axis=2)
Test_vector = np.expand_dims(Test_vector,axis=2)

# %%
X_train = np.array(Training_vector)
Y_train = np.array(Training_label)
X_test = np.array(Test_vector)
Y_test = np.array(Test_label)

# %%
random_index = np.arange(np.shape(X_train)[0])
np.random.shuffle(random_index)

# %%
X_train = X_train[random_index]
Y_train = Y_train[random_index]

# %%
print (np.shape(X_train), np.shape(X_test))
# Out:
# (20250, 1000, 1) (7835, 1000, 1)

# %%
print (np.shape(Y_train), np.shape(Y_test))
# Out:
# (20250, 4) (7835, 4)

# %%
model_m = Sequential()
model_m.add(layers.Conv1D(100, 10, activation='relu', input_shape=(window_size, 1)))
model_m.add(layers.Conv1D(100, 10, activation='relu'))
model_m.add(layers.MaxPooling1D(3))
model_m.add(layers.Conv1D(160, 10, activation='relu'))
model_m.add(layers.Conv1D(160, 10, activation='relu'))
model_m.add(layers.GlobalAveragePooling1D())
model_m.add(layers.Dropout(0.5))
model_m.add(layers.Dense(4, activation='softmax'))
print(model_m.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 991, 100)          1100
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 982, 100)          100100
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 327, 100)          0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 318, 160)          160160
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 309, 160)          256160
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 160)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 160)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 644
# =================================================================
# Total params: 518,164
# Trainable params: 518,164
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    keras.callbacks.EarlyStopping(monitor='acc', patience=1)
]

model_m.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

BATCH_SIZE = 200
EPOCHS = 100

history = model_m.fit(X_train,
                      Y_train,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      validation_data=(X_test,Y_test),
                      verbose=1)
# Out:
# Train on 20250 samples, validate on 7835 samples
# Epoch 1/100
# 20250/20250 [==============================] - 487s 24ms/step - loss: 1.2434 - accuracy: 0.3965 - val_loss: 1.1933 - val_accuracy: 0.4725
# Epoch 2/100
# 20250/20250 [==============================] - 501s 25ms/step - loss: 1.0808 - accuracy: 0.5053 - val_loss: 1.1773 - val_accuracy: 0.4623
# Epoch 3/100
# 20250/20250 [==============================] - 501s 25ms/step - loss: 1.0250 - accuracy: 0.5278 - val_loss: 1.0758 - val_accuracy: 0.5284
# Epoch 4/100
# 20250/20250 [==============================] - 504s 25ms/step - loss: 0.9894 - accuracy: 0.5494 - val_loss: 1.1068 - val_accuracy: 0.5045
# Epoch 5/100
# 20250/20250 [==============================] - 496s 25ms/step - loss: 0.9557 - accuracy: 0.5624 - val_loss: 1.1261 - val_accuracy: 0.4776
# Epoch 6/100
# 20250/20250 [==============================] - 493s 24ms/step - loss: 0.9448 - accuracy: 0.5712 - val_loss: 1.0431 - val_accuracy: 0.5368
# Epoch 7/100
# 20250/20250 [==============================] - 503s 25ms/step - loss: 0.9225 - accuracy: 0.5828 - val_loss: 1.0280 - val_accuracy: 0.5497
# Epoch 8/100
# 20250/20250 [==============================] - 501s 25ms/step - loss: 0.9146 - accuracy: 0.5874 - val_loss: 1.0391 - val_accuracy: 0.5528
# Epoch 9/100
# 20250/20250 [==============================] - 503s 25ms/step - loss: 0.8926 - accuracy: 0.5975 - val_loss: 1.0265 - val_accuracy: 0.5507
# Epoch 10/100
# 20250/20250 [==============================] - 486s 24ms/step - loss: 0.8976 - accuracy: 0.5981 - val_loss: 1.0232 - val_accuracy: 0.5664
# Epoch 11/100
# 20250/20250 [==============================] - 500s 25ms/step - loss: 0.8868 - accuracy: 0.6062 - val_loss: 1.0174 - val_accuracy: 0.5575
# Epoch 12/100
# 20250/20250 [==============================] - 500s 25ms/step - loss: 0.8732 - accuracy: 0.6134 - val_loss: 1.0247 - val_accuracy: 0.5461
# Epoch 13/100
# 20250/20250 [==============================] - 504s 25ms/step - loss: 0.8640 - accuracy: 0.6160 - val_loss: 1.0763 - val_accuracy: 0.5461
# Epoch 14/100
# 20250/20250 [==============================] - 637s 31ms/step - loss: 0.8662 - accuracy: 0.6179 - val_loss: 1.0362 - val_accuracy: 0.5621
# Epoch 15/100
# 20250/20250 [==============================] - 616s 30ms/step - loss: 0.8414 - accuracy: 0.6239 - val_loss: 1.0258 - val_accuracy: 0.5607
# Epoch 16/100
# 20250/20250 [==============================] - 634s 31ms/step - loss: 0.8375 - accuracy: 0.6293 - val_loss: 1.0033 - val_accuracy: 0.5780
# Epoch 17/100
# 20250/20250 [==============================] - 634s 31ms/step - loss: 0.8288 - accuracy: 0.6359 - val_loss: 1.0153 - val_accuracy: 0.5631
# Epoch 18/100
# 20250/20250 [==============================] - 635s 31ms/step - loss: 0.8139 - accuracy: 0.6416 - val_loss: 1.0471 - val_accuracy: 0.5546
# Epoch 19/100
# 20250/20250 [==============================] - 624s 31ms/step - loss: 0.8218 - accuracy: 0.6402 - val_loss: 1.0798 - val_accuracy: 0.5472
# Epoch 20/100
# 20250/20250 [==============================] - 624s 31ms/step - loss: 0.8062 - accuracy: 0.6460 - val_loss: 1.0878 - val_accuracy: 0.5465
# Epoch 21/100
# 20250/20250 [==============================] - 633s 31ms/step - loss: 0.7960 - accuracy: 0.6520 - val_loss: 1.0328 - val_accuracy: 0.5447
# Epoch 22/100
# 20250/20250 [==============================] - 586s 29ms/step - loss: 0.7857 - accuracy: 0.6532 - val_loss: 1.0286 - val_accuracy: 0.5732
# Epoch 23/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.7783 - accuracy: 0.6590 - val_loss: 1.0176 - val_accuracy: 0.5885
# Epoch 24/100
# 20250/20250 [==============================] - 460s 23ms/step - loss: 0.7796 - accuracy: 0.6568 - val_loss: 0.9952 - val_accuracy: 0.5902
# Epoch 25/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.7714 - accuracy: 0.6640 - val_loss: 1.0016 - val_accuracy: 0.5867
# Epoch 26/100
# 20250/20250 [==============================] - 460s 23ms/step - loss: 0.7595 - accuracy: 0.6683 - val_loss: 1.0224 - val_accuracy: 0.5760
# Epoch 27/100
# 20250/20250 [==============================] - 460s 23ms/step - loss: 0.7504 - accuracy: 0.6712 - val_loss: 0.9668 - val_accuracy: 0.5986
# Epoch 28/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.7485 - accuracy: 0.6730 - val_loss: 1.0102 - val_accuracy: 0.5830
# Epoch 29/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.7500 - accuracy: 0.6730 - val_loss: 1.0429 - val_accuracy: 0.5830
# Epoch 30/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.7366 - accuracy: 0.6815 - val_loss: 0.9789 - val_accuracy: 0.5926
# Epoch 31/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.7212 - accuracy: 0.6840 - val_loss: 1.0353 - val_accuracy: 0.5914
# Epoch 32/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.7237 - accuracy: 0.6847 - val_loss: 1.0372 - val_accuracy: 0.5632
# Epoch 33/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.7145 - accuracy: 0.6900 - val_loss: 1.0303 - val_accuracy: 0.5481
# Epoch 34/100
# 20250/20250 [==============================] - 456s 23ms/step - loss: 0.7152 - accuracy: 0.6879 - val_loss: 1.0375 - val_accuracy: 0.5879
# Epoch 35/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.7152 - accuracy: 0.6911 - val_loss: 0.9661 - val_accuracy: 0.5990
# Epoch 36/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.7043 - accuracy: 0.6914 - val_loss: 1.0290 - val_accuracy: 0.5723
# Epoch 37/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.6907 - accuracy: 0.7007 - val_loss: 1.0731 - val_accuracy: 0.5644
# Epoch 38/100
# 20250/20250 [==============================] - 456s 23ms/step - loss: 0.6973 - accuracy: 0.6945 - val_loss: 1.0208 - val_accuracy: 0.5832
# Epoch 39/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.6806 - accuracy: 0.7067 - val_loss: 1.0186 - val_accuracy: 0.6060
# Epoch 40/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.6755 - accuracy: 0.7075 - val_loss: 0.9982 - val_accuracy: 0.6073
# Epoch 41/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.6745 - accuracy: 0.7076 - val_loss: 1.0516 - val_accuracy: 0.6015
# Epoch 42/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.6677 - accuracy: 0.7101 - val_loss: 1.0368 - val_accuracy: 0.5759
# Epoch 43/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.6661 - accuracy: 0.7152 - val_loss: 1.0334 - val_accuracy: 0.5832
# Epoch 44/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.6621 - accuracy: 0.7151 - val_loss: 1.0378 - val_accuracy: 0.5856
# Epoch 45/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.6492 - accuracy: 0.7181 - val_loss: 1.0958 - val_accuracy: 0.5796
# Epoch 46/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.6532 - accuracy: 0.7184 - val_loss: 1.0265 - val_accuracy: 0.5944
# Epoch 47/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.6376 - accuracy: 0.7208 - val_loss: 1.0489 - val_accuracy: 0.5932
# Epoch 48/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.6458 - accuracy: 0.7221 - val_loss: 1.0023 - val_accuracy: 0.6000
# Epoch 49/100
# 20250/20250 [==============================] - 460s 23ms/step - loss: 0.6329 - accuracy: 0.7270 - val_loss: 1.0564 - val_accuracy: 0.5833
# Epoch 50/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.6223 - accuracy: 0.7309 - val_loss: 1.0682 - val_accuracy: 0.6171
# Epoch 51/100
# 20250/20250 [==============================] - 462s 23ms/step - loss: 0.6303 - accuracy: 0.7296 - val_loss: 1.1211 - val_accuracy: 0.5996
# Epoch 52/100
# 20250/20250 [==============================] - 461s 23ms/step - loss: 0.6264 - accuracy: 0.7304 - val_loss: 1.0598 - val_accuracy: 0.6059
# Epoch 53/100
# 20250/20250 [==============================] - 461s 23ms/step - loss: 0.6087 - accuracy: 0.7365 - val_loss: 1.0457 - val_accuracy: 0.6168
# Epoch 54/100
# 20250/20250 [==============================] - 456s 23ms/step - loss: 0.6003 - accuracy: 0.7443 - val_loss: 1.0422 - val_accuracy: 0.6034
# Epoch 55/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.6066 - accuracy: 0.7386 - val_loss: 1.1071 - val_accuracy: 0.6096
# Epoch 56/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.6002 - accuracy: 0.7402 - val_loss: 1.0984 - val_accuracy: 0.5736
# Epoch 57/100
# 20250/20250 [==============================] - 461s 23ms/step - loss: 0.5950 - accuracy: 0.7429 - val_loss: 1.1465 - val_accuracy: 0.6203
# Epoch 58/100
# 20250/20250 [==============================] - 461s 23ms/step - loss: 0.5987 - accuracy: 0.7404 - val_loss: 1.0717 - val_accuracy: 0.5959
# Epoch 59/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.5820 - accuracy: 0.7501 - val_loss: 1.0453 - val_accuracy: 0.6121
# Epoch 60/100
# 20250/20250 [==============================] - 455s 22ms/step - loss: 0.5816 - accuracy: 0.7526 - val_loss: 1.1022 - val_accuracy: 0.6248
# Epoch 61/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.5778 - accuracy: 0.7540 - val_loss: 1.1403 - val_accuracy: 0.6102
# Epoch 62/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5585 - accuracy: 0.7600 - val_loss: 1.1322 - val_accuracy: 0.6098
# Epoch 63/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.5575 - accuracy: 0.7588 - val_loss: 1.0894 - val_accuracy: 0.6156
# Epoch 64/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5597 - accuracy: 0.7598 - val_loss: 1.0740 - val_accuracy: 0.6243
# Epoch 65/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.5600 - accuracy: 0.7607 - val_loss: 1.1252 - val_accuracy: 0.6026
# Epoch 66/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.5509 - accuracy: 0.7623 - val_loss: 1.1469 - val_accuracy: 0.5920
# Epoch 67/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.5436 - accuracy: 0.7681 - val_loss: 1.1162 - val_accuracy: 0.6077
# Epoch 68/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5417 - accuracy: 0.7721 - val_loss: 1.0769 - val_accuracy: 0.6249
# Epoch 69/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5463 - accuracy: 0.7655 - val_loss: 1.1640 - val_accuracy: 0.6197
# Epoch 70/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.5333 - accuracy: 0.7748 - val_loss: 1.1940 - val_accuracy: 0.6008
# Epoch 71/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.5322 - accuracy: 0.7733 - val_loss: 1.1741 - val_accuracy: 0.5994
# Epoch 72/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5310 - accuracy: 0.7731 - val_loss: 1.1463 - val_accuracy: 0.6069
# Epoch 73/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.5248 - accuracy: 0.7818 - val_loss: 1.2588 - val_accuracy: 0.6078
# Epoch 74/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5170 - accuracy: 0.7842 - val_loss: 1.1595 - val_accuracy: 0.6116
# Epoch 75/100
# 20250/20250 [==============================] - 460s 23ms/step - loss: 0.5078 - accuracy: 0.7855 - val_loss: 1.2683 - val_accuracy: 0.5761
# Epoch 76/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.5171 - accuracy: 0.7804 - val_loss: 1.2188 - val_accuracy: 0.6098
# Epoch 77/100
# 20250/20250 [==============================] - 460s 23ms/step - loss: 0.4926 - accuracy: 0.7912 - val_loss: 1.2262 - val_accuracy: 0.5949
# Epoch 78/100
# 20250/20250 [==============================] - 456s 22ms/step - loss: 0.5021 - accuracy: 0.7897 - val_loss: 1.4183 - val_accuracy: 0.5599
# Epoch 79/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5008 - accuracy: 0.7876 - val_loss: 1.3519 - val_accuracy: 0.6033
# Epoch 80/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.5056 - accuracy: 0.7880 - val_loss: 1.3056 - val_accuracy: 0.6036
# Epoch 81/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.4908 - accuracy: 0.7899 - val_loss: 1.2369 - val_accuracy: 0.6186
# Epoch 82/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.4827 - accuracy: 0.7963 - val_loss: 1.2766 - val_accuracy: 0.5917
# Epoch 83/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.4790 - accuracy: 0.7975 - val_loss: 1.2841 - val_accuracy: 0.6225
# Epoch 84/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.4825 - accuracy: 0.7962 - val_loss: 1.2459 - val_accuracy: 0.6073
# Epoch 85/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.4728 - accuracy: 0.8020 - val_loss: 1.3534 - val_accuracy: 0.6189
# Epoch 86/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.4696 - accuracy: 0.8014 - val_loss: 1.3669 - val_accuracy: 0.6172
# Epoch 87/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.4647 - accuracy: 0.8029 - val_loss: 1.3349 - val_accuracy: 0.6253
# Epoch 88/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.4549 - accuracy: 0.8074 - val_loss: 1.3240 - val_accuracy: 0.6188
# Epoch 89/100
# 20250/20250 [==============================] - 459s 23ms/step - loss: 0.4537 - accuracy: 0.8098 - val_loss: 1.2718 - val_accuracy: 0.6223
# Epoch 90/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.4438 - accuracy: 0.8105 - val_loss: 1.4208 - val_accuracy: 0.5971
# Epoch 91/100
# 20250/20250 [==============================] - 458s 23ms/step - loss: 0.4467 - accuracy: 0.8121 - val_loss: 1.2482 - val_accuracy: 0.6112
# Epoch 92/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.4535 - accuracy: 0.8118 - val_loss: 1.3585 - val_accuracy: 0.5823
# Epoch 93/100
# 20250/20250 [==============================] - 455s 22ms/step - loss: 0.4424 - accuracy: 0.8170 - val_loss: 1.4946 - val_accuracy: 0.6084
# Epoch 94/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.4385 - accuracy: 0.8179 - val_loss: 1.4990 - val_accuracy: 0.6227
# Epoch 95/100
# 20250/20250 [==============================] - 457s 23ms/step - loss: 0.4334 - accuracy: 0.8182 - val_loss: 1.5309 - val_accuracy: 0.5796
# Epoch 96/100
# 20250/20250 [==============================] - 452s 22ms/step - loss: 0.4242 - accuracy: 0.8238 - val_loss: 1.3633 - val_accuracy: 0.6309
# Epoch 97/100
# 20250/20250 [==============================] - 307s 15ms/step - loss: 0.4274 - accuracy: 0.8231 - val_loss: 1.4114 - val_accuracy: 0.6228
# Epoch 98/100
# 20250/20250 [==============================] - 305s 15ms/step - loss: 0.4174 - accuracy: 0.8268 - val_loss: 1.4071 - val_accuracy: 0.6208
# Epoch 99/100
# 20250/20250 [==============================] - 306s 15ms/step - loss: 0.4264 - accuracy: 0.8240 - val_loss: 1.2975 - val_accuracy: 0.6273
# Epoch 100/100
# 20250/20250 [==============================] - 306s 15ms/step - loss: 0.4151 - accuracy: 0.8285 - val_loss: 1.4977 - val_accuracy: 0.5861

# %%
import matplotlib.pyplot as plt

acc = history.history["acc"]
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs= range(1,len(acc)+1)

plt.plot(epochs, acc, 'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label = 'Validation a cc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss,'b',label = 'Validation loss')
plt.title('Training an validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-fdc69ba0ee3f> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 acc = history.history["acc"]
#       4 val_acc = history.history['val_acc']
#       5 loss = history.history['loss']
#
# KeyError: 'acc'

# %%
acc =model_m.evaluate(X_test,Y_test)

# %%
print (acc[1])

# %%
model_m.save("Conv1D_DNN_subject_windowing7000_class4.h5")
